# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('placement.csv')
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
X_train,X_test,y_train,y_test = train_test_split(df.iloc[:,0].values,df.iloc[:,1].values,test_size=0.3,random_state=42)

# %%
X_train
# Out:
# array([9.31, 5.98, 8.1 , 8.94, 6.87, 7.39, 5.95, 8.11, 7.11, 5.64, 9.26,
#        6.78, 5.53, 6.89, 7.4 , 6.94, 8.31, 7.19, 7.95, 5.42, 7.82, 8.99,
#        6.07, 6.26, 7.28, 4.79, 7.3 , 5.99, 6.19, 5.48, 6.14, 6.76, 6.71,
#        6.35, 6.61, 7.89, 8.71, 6.73, 5.42, 5.23, 6.94, 6.96, 6.93, 5.84,
#        7.77, 6.17, 5.32, 6.34, 8.58, 6.07, 8.6 , 6.89, 7.63, 7.94, 5.79,
#        5.1 , 7.36, 5.09, 8.93, 5.94, 9.38, 7.76, 6.98, 7.38, 7.28, 6.19,
#        7.88, 5.66, 6.1 , 7.43, 8.65, 5.84, 5.83, 7.08, 7.66, 7.91, 7.42,
#        6.66, 6.47, 6.05, 6.19, 8.15, 6.31, 8.87, 7.63, 7.34, 6.75, 8.18,
#        6.22, 8.44, 6.29, 8.22, 6.42, 6.09, 6.93, 7.56, 8.01, 6.37, 5.38,
#        7.78, 7.04, 7.2 , 8.13, 7.28, 9.16, 6.86, 6.33, 9.58, 5.89, 6.92,
#        8.63, 4.73, 6.85, 6.6 , 7.13, 8.25, 7.29, 5.9 , 6.47, 4.57, 5.12,
#        8.37, 8.28, 6.68, 6.12, 7.05, 6.61, 9.04, 8.09, 6.85, 6.5 , 6.22,
#        7.28, 7.35, 7.47, 6.13, 7.73, 7.9 , 7.14, 5.13])

# %%
class MyLinearRegression:
    def __init__(self):
        self.m = None
        self.b = None

    def fit(self,X,y):
        X_mean = X.mean()
        y_mean = y.mean()

        num = 0
        den = 0
        for i in range(len(X)):
            num += ((X[i]-X_mean)*(y[i]-y_mean))
            den += ((X[i]-X_mean)**2)

        self.m = num/den
        self.b = y_mean - self.m*X_mean
        print(self.m)
        print(self.b)

    def predict(self,X_test):
        return X_test*self.m + self.b

# %%
lr = MyLinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# 0.5701809395087659
# -0.9808837676635771

# %%
lr.predict(X_test[0])
# Out:
# 2.799415861279541

# %%
from sklearn.linear_model import LinearRegression

# %%
lr1 = LinearRegression()

# %%
X_train.reshape(-1,1)
# Out:
# array([[9.31],
#        [5.98],
#        [8.1 ],
#        [8.94],
#        [6.87],
#        [7.39],
#        [5.95],
#        [8.11],
#        [7.11],
#        [5.64],
#        [9.26],
#        [6.78],
#        [5.53],
#        [6.89],
#        [7.4 ],
#        [6.94],
#        [8.31],
#        [7.19],
#        [7.95],
#        [5.42],
#        [7.82],
#        [8.99],
#        [6.07],
#        [6.26],
#        [7.28],
#        [4.79],
#        [7.3 ],
#        [5.99],
#        [6.19],
#        [5.48],
#        [6.14],
#        [6.76],
#        [6.71],
#        [6.35],
#        [6.61],
#        [7.89],
#        [8.71],
#        [6.73],
#        [5.42],
#        [5.23],
#        [6.94],
#        [6.96],
#        [6.93],
#        [5.84],
#        [7.77],
#        [6.17],
#        [5.32],
#        [6.34],
#        [8.58],
#        [6.07],
#        [8.6 ],
#        [6.89],
#        [7.63],
#        [7.94],
#        [5.79],
#        [5.1 ],
#        [7.36],
#        [5.09],
# ...

# %%
X_train1,X_test1,y_train1,y_test1 = train_test_split(df.iloc[:,0:1],df.iloc[:,-1],test_size=0.3,random_state=42)

# %%
lr1.fit(X_train1,y_train1)
# Out:
# LinearRegression()

# %%
y_predict = lr1.predict(X_test1)

# %%
y_predict
# Out:
# array([2.79941586, 3.15292804, 3.21564795, 2.41169282, 3.54065108,
#        3.78012708, 3.18143709, 2.56564168, 3.19284071, 3.50644023,
#        1.93274083, 2.37178016, 3.70030175, 2.77660862, 3.4893348 ,
#        3.06169909, 2.34897292, 3.22134976, 2.20072587, 3.32968414,
#        2.47441273, 2.91915386, 3.33538594, 2.89064481, 3.35249137,
#        2.2178313 , 1.44808703, 2.73099415, 3.19854252, 2.34897292,
#        3.75731984, 2.97617195, 3.69459994, 2.99327738, 2.61125615,
#        3.36389499, 2.49721996, 3.09020814, 4.18495554, 2.97617195,
#        3.11301538, 3.13012081, 3.93407593, 2.74239777, 1.93844264,
#        2.97047014, 3.09590995, 3.28406966, 1.78449379, 3.35819318,
#        2.34897292, 2.86783757, 3.51784385, 2.38888558, 3.07880452,
#        3.83144336, 3.52924746, 3.40380766, 2.97047014, 3.07310271])

# %%
X_test
# Out:
# array([6.63, 7.25, 7.36, 5.95, 7.93, 8.35, 7.3 , 6.22, 7.32, 7.87, 5.11,
#        5.88, 8.21, 6.59, 7.84, 7.09, 5.84, 7.37, 5.58, 7.56, 6.06, 6.84,
#        7.57, 6.79, 7.6 , 5.61, 4.26, 6.51, 7.33, 5.84, 8.31, 6.94, 8.2 ,
#        6.97, 6.3 , 7.62, 6.1 , 7.14, 9.06, 6.94, 7.18, 7.21, 8.62, 6.53,
#        5.12, 6.93, 7.15, 7.48, 4.85, 7.61, 5.84, 6.75, 7.89, 5.91, 7.12,
#        8.44, 7.91, 7.69, 6.93, 7.11])

# %%
lr.predict(X_test[0])
# Out:
# 2.799415861279541

# %% [raw]
# X_train

# %%
lr1.predict(X_test[0].reshape(1,-1))
# Out:
# C:\Users\aashi\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([2.79941586])

# %%
plt.scatter(df['cgpa'],df['package'])
plt.xlabel('CGPA')
plt.ylabel('package')
plt.plot(X_train1,lr1.predict(X_train1),color='red')

plt.show()
